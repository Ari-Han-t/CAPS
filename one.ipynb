# %%
import requests

BACKBOARD_API_KEY = "espr_iwob45oXNMHEdkEqI-zj6HwwkGRxPj2Im7jLd8WMZU8"
BACKBOARD_API_URL = "https://app.backboard.io/api"

headers = {
    "Authorization": f"Bearer {BACKBOARD_API_KEY}",
    "Content-Type": "application/json"
}

# Try basic endpoint
endpoint = "/"

response = requests.get(
    BACKBOARD_API_URL + endpoint,
    headers=headers
)

print("Status Code:", response.status_code)
print("Response:")
print(response.text)
# Out:
# Status Code: 200
# Response:
# {"message":"Welcome to Backboard API"}
